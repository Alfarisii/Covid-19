# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt


import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Alfarisii/Covid-19/master/world-country.csv")

df.head(10)

#country = df[df.country == "China"]
columns = df[['country','deaths']]
print(columns)

group = df[['country','deaths']].groupby('country').sum().head(7)
print(group)

fig, axes = plt.subplots(figsize=(8,5), dpi=500)
plt.bar(group.index, height=group.deaths)
plt.title('Country');
# Out:
#                  country  deaths
# 0                  China      17
# 1                  China      18
# 2                  China      26
# 3                  China      42
# 4                  China      56
# ...                  ...     ...
# 1432                  US    1581
# 1433          Uzbekistan       1
# 1434           Venezuela       1
# 1435  West Bank and Gaza       1
# 1436            Zimbabwe       1
#
# [1437 rows x 2 columns]
#              deaths
# country
# Afghanistan      13
# Albania          45
# Algeria         185
# Andorra          10
# Argentina        71
# Armenia           2
# Australia       125

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

#pd.set_option('display.max_row', 10000)
#pd.set_option('display.max_columns', 500)


df = pd.read_csv("https://raw.githubusercontent.com/Alfarisii/Covid-19/master/world-country.csv")




date = df [df.date == "2020-01-22"]

#deaths = df['deaths']

print(date)
#print(deaths.sum())


#plt.plot(date, deaths)
#plt.show()

#new = df [['date', 'country', 'deaths_new']]
#print(df)
# Out:
#   File "<ipython-input-36-8ca4d788d0a4>", line 6
#     days = [""name","sunday"]
#                  ^
# SyntaxError: invalid syntax
